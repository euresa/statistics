# %% [markdown]
# # Scraping Wikipedia Pages
# ### Author: Sam Eure
# ### Data: May 12, 2021
#
# In this notebook, I created a short Python script for scraping Wikipedia pages in order to obtain the hyperlinks listed in each section of the Wikipedia pages. Given a link to a Wikipedia page, this script should do the following:
#
# 1) Print the title of the page
#
# 2) Print the header of each section
#
# 3) Print the plain text of each section
#
# 4) Print a list of the hyperlinks referenced in the paragraphs in each section (if present)
#
# Ultimately, I'd like to develop some text based ML models using Wikipedia page data. I think this script will work well for gathering natural language data on a variety of topics!

# %% [markdown]
# ### Functions and Imports

# %%
import re

import pandas as pd
try:
    import requests
except:
    # !python3 -m pip install requests
    import requests
    
try:
    from bs4 import BeautifulSoup
except:
    # !python3 -m pip install beautifulsoup4
    from bs4 import BeautifulSoup

################### INPUTS ###########################

HTML_LINK = "https://en.wikipedia.org/wiki/Statistics"

################## END OF INPUTS #####################

#Scraping
def get_soup_doc(html_link, parser = 'html.parser'):
    '''Takes in an html link and returns a BeautifulSoup document.'''
    response = requests.get(HTML_LINK)
    soup_doc = BeautifulSoup(response.content, 'html.parser')
    return(soup_doc)

def get_title(soup_doc):
    '''Returns the title of the web page.'''
    title = soup_doc.find(id='firstHeading').text
    return(title)

def get_headers(soup):
    '''Returns the header of each section in a Wikipedia page.'''
    headers = soup.find_all('span', attrs='mw-headline')
    return(headers)

def remove_footnotes(text):
    '''Drop footnote superscripts in brackets'''
    text = re.sub(r"\[.*?\]+", '', text)
    return(text)

def get_indices(soup, string_elements):
    '''Returns the a list of the starting index for each element in a list of strings.'''
    soup_string = str(soup)
    indices = [soup_string.index(string) for string in header_strings]
    return(indices)

def get_index(text, element):
    '''Attempts to get the index of an element. Returns None if not present'''
    try:
        idx = text.index(element)
        return(idx)
    except:
        return(None)
    
def combine(lists):
    '''Combines a list of lists into one list to return.'''
    combo = []
    for list_ in lists:
        combo.extend(list_)
    return(combo)

def collect_pattern_pairs(text, start_char, end_char):
    '''Returns a list of all text between sets of start_char and end_char characters.'''
    collection = []
    while get_index(text, start_char) is not None:
        start = get_index(text, start_char)
        end = get_index(text[start:], end_char) + start #make sure end is after start
        collection.append(text[start:end+len(end_char)])
        text = text[end+len(end_char):]
    return(collection)

def get_raw_paragraphs(soup, h_indices, i):
    '''Returns unprocessed HTML paragraphs.'''
    soup_string = str(soup)
    try:
        raw_text_i = soup_string[h_indices[i]:h_indices[i+1]]
    except:
        raw_text_i = soup_string[h_indices[i]:]
    paragraphs = collect_pattern_pairs(raw_text_i, "<p>", "</p>")
    return(paragraphs)

def get_paragraphs(soup, h_indices, i):
    '''Returns the text paragraphs associated with the section header specified by an index.'''
    paragraphs = get_raw_paragraphs(soup, h_indices, i)
    clean_paragraphs = [remove_HTML(p) for p in paragraphs]
    return(clean_paragraphs)

def remove_pattern_pair(text, start_char, end_char):
    '''Removes all text between the start_char and end_char and returns remaining text.'''
    while get_index(text, start_char) is not None:
        start = get_index(text, start_char)
        end = get_index(text[start:], end_char) + start #make sure end is after start
        text = text[:start] + text[end+len(end_char):]
    return(text)

def remove_substrings(text, substring_list):
    '''Removes all occurences of all substrings in a list from a text string. Returns new string.'''
    for pattern in substring_list:
        text = re.sub(pattern, "", text)
    return(text)

def remove_HTML(text):
    '''Removes the HTML elements from a substring of an HTML document and returns resulting string.'''
    to_remove = ['</a>', '</sup>', '<p>', '</p>']
    text = remove_substrings(text, to_remove)
    plain_text = remove_pattern_pair(text, '<', ">")
    plain_text = remove_footnotes(plain_text)
    return(plain_text)

def clean_wiki_links(hlinks):
    '''Completes hyperlinks to other Wikipedia pages.'''
    for i, link in enumerate(hlinks):
        if '/wiki/' in link:
            end = link.index('"')
            hlinks[i] = re.sub('/wiki/', 'https://en.wikipedia.org/wiki/', link[:end])
    return(hlinks)

def remove_internal_links(hlinks):
    '''Removes links that reference different parts of the Wikipedia page.'''
    internal_links = []
    for link in hlinks:
        if "#" == link[0]:
            print(link)
            hlinks.remove(link)
    return(hlinks)
    
def clean_cite_notes(hlinks):
    '''Removes references to links cited at the bottom of the Wikipedia page.'''
    cite_notes = []
    for i, link in enumerate(hlinks):
        if '#cite_note-' in link:
            cite_notes.append(hlinks[i])
    for c in cite_notes:
        hlinks.remove(c)
    return(hlinks)

def clean_hyperlinks(html_hyperlinks):
    '''Removes the HTML markup around hyperlinks and returns a list of hyperlinks'''
    to_remove =['<a href="', '">']
    hlinks = [remove_substrings(link, to_remove) for link in html_hyperlinks]
    hlinks = clean_wiki_links(hlinks)
    hlinks = clean_cite_notes(hlinks)
    hlinks = remove_internal_links(hlinks)
    return(hlinks)

def get_hyperlink(text):
    '''Returns a list of all hyperlinks included in a subsection of an HTML document.'''
    html_hyperlinks = collect_pattern_pairs(text, '<a href=', '>')
    hyperlinks = clean_hyperlinks(html_hyperlinks)
    return(hyperlinks)

def show_some_text(text):
    '''Returns first 100 characters in string.'''
    return(text[:100]+"...")


#Processing
def join_paragraphs(p_list, join_char = ' \n '):
    return(join_char.join(p_list))

def get_words_from_paragraphs(p_list):
    paragraph = join_paragraphs(p_list)
    return(paragraph.split(" "))

def add_count_feature(df, feature):
    df[feature+"_count"] = df.apply(lambda row : len(row[feature]), axis=1)
    return(df)

# %% [markdown]
# ### Scraping the Data

# %%
soup = get_soup_doc(HTML_LINK)
headers = get_headers(soup)
header_strings = [str(h) for h in headers]
h_indices = get_indices(soup, header_strings)

#Printing
hyperlinks = []
para_list = []
section_headers = []
print('PAGE TITLE:',get_title(soup))
for i, head in enumerate(headers):
    section_headers.append(head.text)
    print("\n","#"*100, '\n\tSECTION:', head.text)
    paragraphs = get_raw_paragraphs(soup, h_indices, i)
    hrefs = [get_hyperlink(p) for p in paragraphs]
    paras = [remove_HTML(p) for p in paragraphs]
    hyperlinks.append(combine(hrefs))
    para_list.append(paras)
    for p in paras:
        print('\n', show_some_text(p))
    print('\nLINKS:', show_some(str(combine(hrefs))))
# Out:
# PAGE TITLE: Statistics
#
#  ####################################################################################################
# 	SECTION: Introduction
#
#  Statistics is a mathematical body of science that pertains to the collection, analysis, interpretati...
#
#  In applying statistics to a problem, it is common practice to start with a population or process to ...
#
#  When a census is not feasible, a chosen subset of the population called a sample is studied. Once a ...
#
# LINKS: ['https://en.wikipedia.org/wiki/Data', 'https://en.wikipedia.org/wiki/Mathematics', 'https://en.wiki...
#
#  ####################################################################################################
# 	SECTION: Mathematical statistics
#
#  Mathematical statistics is the application of mathematics to statistics. Mathematical techniques use...
#
# LINKS: ['https://en.wikipedia.org/wiki/Mathematics', 'https://en.wikipedia.org/wiki/Mathematical_analysis',...
#
#  ####################################################################################################
# 	SECTION: History
#
#  The early writings on statistical interference date back to Arab mathematicians and cryptographers, ...
#
#  The earliest European writing on statistics dates back to 1663, with the publication of Natural and ...
#
#  The mathematical foundations of modern statistics were laid in the 17th century with the development...
#
#  The modern field of statistics emerged in the late 19th and early 20th century in three stages. The ...
#
#  Ronald Fisher coined the term null hypothesis during the Lady tasting tea experiment, which "is neve...
#
#  The second wave of the 1910s and 20s was initiated by William Sealy Gosset, and reached its culminat...
#
#  The final wave, which mainly saw the refinement and expansion of earlier developments, emerged from ...
#
#  Today, statistical methods are applied in all fields that involve decision making, for making accura...
#
# LINKS: ['https://en.wikipedia.org/wiki/Mathematics_in_medieval_Islam', 'https://en.wikipedia.org/wiki/Islam...
#
#  ####################################################################################################
# 	SECTION: Statistical data
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Data collection
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Sampling
#
#  When full census data cannot be collected, statisticians collect sample data by developing specific ...
#
#  To use a sample as a guide to an entire population, it is important that it truly represents the ove...
#
#  Sampling theory is part of the mathematical discipline of probability theory. Probability is used in...
#
# LINKS: ['https://en.wikipedia.org/wiki/Design_of_experiments', 'https://en.wikipedia.org/wiki/Survey_sampli...
#
#  ####################################################################################################
# 	SECTION: Experimental and observational studies
#
#  A common goal for a statistical research project is to investigate causality, and in particular to d...
#
# LINKS: ['https://en.wikipedia.org/wiki/Causality', 'https://en.wikipedia.org/wiki/Dependent_and_independent...
#
#  ####################################################################################################
# 	SECTION: Experiments
#
#  The basic steps of a statistical experiment are:
# ...
#
#  Experiments on human behavior have special concerns. The famous Hawthorne study examined changes to ...
#
# LINKS: ['https://en.wikipedia.org/wiki/Assembly_line', 'https://en.wikipedia.org/wiki/Hawthorne_effect']...
#
#  ####################################################################################################
# 	SECTION: Observational study
#
#  An example of an observational study is one that explores the association between smoking and lung c...
#
# LINKS: ['https://en.wikipedia.org/wiki/Cohort_study']...
#
#  ####################################################################################################
# 	SECTION: Types of data
#
#  Various attempts have been made to produce a taxonomy of levels of measurement. The psychophysicist ...
#
#  Because variables conforming only to nominal or ordinal measurements cannot be reasonably measured n...
#
#  Other categorizations have been proposed. For example, Mosteller and Tukey (1977) distinguished grad...
#
#  The issue of whether or not it is appropriate to apply different kinds of statistical methods to dat...
#
# LINKS: ['https://en.wikipedia.org/wiki/Level_of_measurement', 'https://en.wikipedia.org/wiki/Stanley_Smith_...
#
#  ####################################################################################################
# 	SECTION: Methods
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Descriptive statistics
#
#  A descriptive statistic (in the count noun sense) is a summary statistic that quantitatively describ...
#
# LINKS: ['https://en.wikipedia.org/wiki/Count_noun', 'https://en.wikipedia.org/wiki/Information', 'https://e...
#
#  ####################################################################################################
# 	SECTION: Inferential statistics
#
#  Statistical inference is the process of using data analysis to deduce properties of an underlying pr...
#
# LINKS: ['https://en.wikipedia.org/wiki/Data_analysis', 'https://en.wikipedia.org/wiki/Probability_distribut...
#
#  ####################################################################################################
# 	SECTION: Terminology and theory of inferential statistics
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Statistics, estimators and pivotal quantities
#
#  Consider independent identically distributed (IID) random variables with a given probability distrib...
#
#  A statistic is a random variable that is a function of the random sample, but not a is a statistic u...
#
#  A random variable that is a function of the random sample and of the unknown parameter, but whose pr...
#
#  Between two estimators of a given parameter, the one with lower mean squared error is said to be mor...
#
#  Other desirable properties for estimators include: UMVUE estimators that have the lowest variance fo...
#
#  This still leaves the question of how to obtain estimators in a given situation and carry the comput...
#
# LINKS: ['https://en.wikipedia.org/wiki/Probability_distribution', 'https://en.wikipedia.org/wiki/Statistica...
#
#  ####################################################################################################
# 	SECTION: Null hypothesis and alternative hypothesis
#
#  Interpretation of statistical information can often involve the development of a null hypothesis whi...
#
#  The best illustration for a novice is the predicament encountered by a criminal trial. The null hypo...
#
#  What statisticians call an alternative hypothesis is simply a hypothesis that contradicts the null h...
#
# LINKS: ['https://en.wikipedia.org/wiki/Alternative_hypothesis']...
#
#  ####################################################################################################
# 	SECTION: Error
#
#  Working from a null hypothesis, two broad categories of error are recognized:
# ...
#
#  Standard deviation refers to the extent to which individual observations in a sample differ from a c...
#
#  A statistical error is the amount by which an observation differs from its expected value, a residua...
#
#  Mean squared error is used for obtaining efficient estimators, a widely used class of estimators. Ro...
#
#  Many statistical methods seek to minimize the residual sum of squares, and these are called "methods...
#
#  Measurement processes that generate statistical data are also subject to error.  Many of these error...
#
# LINKS: ['https://en.wikipedia.org/wiki/Standard_deviation', 'https://en.wikipedia.org/wiki/Expected_value',...
#
#  ####################################################################################################
# 	SECTION: Interval estimation
#
#  Most studies only sample part of a population, so results don't fully represent the whole population...
#
#  In principle confidence intervals can be symmetrical or asymmetrical. An interval can be asymmetrica...
#
# LINKS: ['https://en.wikipedia.org/wiki/Frequentist_inference', 'https://en.wikipedia.org/wiki/Random_variab...
#
#  ####################################################################################################
# 	SECTION: Significance
#
#  Statistics rarely give a simple Yes/No type answer to the question under analysis. Interpretation of...
#
#  The standard approach is to test a null hypothesis against an alternative hypothesis. A critical reg...
#
#  Referring to statistical significance does not necessarily mean that the overall result is significa...
#
#  Although in principle the acceptable level of statistical significance may be subject to debate, the...
#
#  Some problems are usually associated with this framework (See criticism of hypothesis testing):
# ...
#
# LINKS: ['https://en.wikipedia.org/wiki/P-value', 'https://en.wikipedia.org/wiki/Statistical_significance', ...
#
#  ####################################################################################################
# 	SECTION: Examples
#  Some well-known statistical tests and procedures are:
# ...
#
# LINKS: ['https://en.wikipedia.org/wiki/Statistical_hypothesis_testing']...
#
#  ####################################################################################################
# 	SECTION: Exploratory data analysis
#
#  Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main charac...
#
# LINKS: ['https://en.wikipedia.org/wiki/Data_analysis', 'https://en.wikipedia.org/wiki/Data_set', 'https://e...
#
#  ####################################################################################################
# 	SECTION: Misuse
#
#  Misuse of statistics can produce subtle but serious errors in description and interpretation—subtle ...
#
#  Even when statistical techniques are correctly applied, the results can be difficult to interpret fo...
#
#  There is a general perception that statistical knowledge is all-too-frequently intentionally misused...
#
#  Ways to avoid misuse of statistics include using proper diagrams and avoiding bias. Misuse can occur...
#
#  To assist in the understanding of statistics Huff proposed a series of questions to be asked in each...
#
# LINKS: ['https://en.wikipedia.org/wiki/Misuse_of_statistics', 'https://en.wikipedia.org/wiki/Statistical_si...
#
#  ####################################################################################################
# 	SECTION: Misinterpretation: correlation
#
#  The concept of correlation is particularly noteworthy for the potential confusion it can cause. Stat...
#
# LINKS: ['https://en.wikipedia.org/wiki/Data_set']...
#
#  ####################################################################################################
# 	SECTION: Applications
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Applied statistics, theoretical statistics and mathematical statistics
#
#  Applied statistics comprises descriptive statistics and the application of inferential statistics. T...
#
#  Statistical consultants can help organizations and companies that don't have in-house expertise rele...
#
# LINKS: ['https://en.wikipedia.org/wiki/Statistical_inference', 'https://en.wikipedia.org/wiki/Probability_d...
#
#  ####################################################################################################
# 	SECTION: Machine learning and data mining
#
#  Machine learning models are statistical and probabilistic models that capture patterns in the data t...
#
# LINKS: ['https://en.wikipedia.org/wiki/Machine_learning']...
#
#  ####################################################################################################
# 	SECTION: Statistics in academia
#
#  Statistics is applicable to a wide variety of academic disciplines, including natural and social sci...
#
#  A typical statistics course covers descriptive statistics, probability, binomial and normal distribu...
#
# LINKS: ['https://en.wikipedia.org/wiki/Academic_discipline', 'https://en.wikipedia.org/wiki/Natural_science...
#
#  ####################################################################################################
# 	SECTION: Statistical computing
#
#  The rapid and sustained increases in computing power starting from the second half of the 20th centu...
#
#  Increased computing power has also led to the growing popularity of computationally intensive method...
#
# LINKS: ['https://en.wikipedia.org/wiki/Linear_model', 'https://en.wikipedia.org/wiki/Nonlinear_regression',...
#
#  ####################################################################################################
# 	SECTION: Business statistics
#
#  In business, "statistics" is a widely used management- and decision support tool.
# It is particularly...
#
#  A typical "Business Statistics" course is intended for business majors,
# and covers
#
# descriptive s...
#
# LINKS: ['https://en.wikipedia.org/wiki/Management#Nature_of_work', 'https://en.wikipedia.org/wiki/Financial...
#
#  ####################################################################################################
# 	SECTION: Statistics applied to mathematics or the arts
#
#  Traditionally, statistics was concerned with drawing inferences using a semi-standardized methodolog...
#
# LINKS: ['https://en.wikipedia.org/wiki/Wikipedia:Citation_needed', 'https://en.wikipedia.org/wiki/Wikipedia...
#
#  ####################################################################################################
# 	SECTION: Specialized disciplines
#
#  Statistical techniques are used in a wide range of types of scientific and social research, includin...
#
#  In addition, there are particular types of statistical analysis that have also developed their own s...
#
#  Statistics form a key basis tool in business and manufacturing as well. It is used to understand mea...
#
# LINKS: ['https://en.wikipedia.org/wiki/Biostatistics', 'https://en.wikipedia.org/wiki/Computational_biology...
#
#  ####################################################################################################
# 	SECTION: See also
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: References
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: Further reading
#
# LINKS: []...
#
#  ####################################################################################################
# 	SECTION: External links
#
# LINKS: []...

# %% [markdown]
# Some of the sections don't have any paragraphs associated with them. This is because I assigned paragraphs to more specific subsections as opposed to sections as a whole. I'll organize this data into a dataframe now.

# %% [markdown]
# ### Organizing the Data

# %%
wiki_df = pd.DataFrame({'section': section_headers, "hyperlinks": hyperlinks, 'paragraphs': para_list})
wiki_df['words'] = wiki_df.apply(lambda row : get_words_from_paragraphs(row.paragraphs), axis=1)
wiki_df = add_count_feature(wiki_df, 'hyperlinks')
wiki_df = add_count_feature(wiki_df, 'paragraphs')
wiki_df = add_count_feature(wiki_df, 'words')
wiki_df = wiki_df.set_index('section')
wiki_df = wiki_df[~(wiki_df.paragraphs_count==0)]
wiki_df
# Out:
#                                                                                            hyperlinks  \
# section
# Introduction                                        [https://en.wikipedia.org/wiki/Data, https://e...
# Mathematical statistics                             [https://en.wikipedia.org/wiki/Mathematics, ht...
# History                                             [https://en.wikipedia.org/wiki/Mathematics_in_...
# Sampling                                            [https://en.wikipedia.org/wiki/Design_of_exper...
# Experimental and observational studies              [https://en.wikipedia.org/wiki/Causality, http...
# Experiments                                         [https://en.wikipedia.org/wiki/Assembly_line, ...
# Observational study                                      [https://en.wikipedia.org/wiki/Cohort_study]
# Types of data                                       [https://en.wikipedia.org/wiki/Level_of_measur...
# Descriptive statistics                              [https://en.wikipedia.org/wiki/Count_noun, htt...
# Inferential statistics                              [https://en.wikipedia.org/wiki/Data_analysis, ...
# Statistics, estimators and pivotal quantities       [https://en.wikipedia.org/wiki/Probability_dis...
# Null hypothesis and alternative hypothesis          [https://en.wikipedia.org/wiki/Alternative_hyp...
# Error                                               [https://en.wikipedia.org/wiki/Standard_deviat...
# Interval estimation                                 [https://en.wikipedia.org/wiki/Frequentist_inf...
# Significance                                        [https://en.wikipedia.org/wiki/P-value, https:...
# Examples                                            [https://en.wikipedia.org/wiki/Statistical_hyp...
# Exploratory data analysis                           [https://en.wikipedia.org/wiki/Data_analysis, ...
# Misuse                                              [https://en.wikipedia.org/wiki/Misuse_of_stati...
# Misinterpretation: correlation                               [https://en.wikipedia.org/wiki/Data_set]
# Applied statistics, theoretical statistics and ...  [https://en.wikipedia.org/wiki/Statistical_inf...
# Machine learning and data mining                     [https://en.wikipedia.org/wiki/Machine_learning]
# Statistics in academia                              [https://en.wikipedia.org/wiki/Academic_discip...
# Statistical computing                               [https://en.wikipedia.org/wiki/Linear_model, h...
# Business statistics                                 [https://en.wikipedia.org/wiki/Management#Natu...
# Statistics applied to mathematics or the arts       [https://en.wikipedia.org/wiki/Wikipedia:Citat...
# Specialized disciplines                             [https://en.wikipedia.org/wiki/Biostatistics, ...
#
#                                                                                            paragraphs  \
# section
# Introduction                                        [Statistics is a mathematical body of science ...
# Mathematical statistics                             [Mathematical statistics is the application of...
# History                                             [The early writings on statistical interferenc...
# Sampling                                            [When full census data cannot be collected, st...
# Experimental and observational studies              [A common goal for a statistical research proj...
# Experiments                                         [The basic steps of a statistical experiment a...
# Observational study                                 [An example of an observational study is one t...
# Types of data                                       [Various attempts have been made to produce a ...
# Descriptive statistics                              [A descriptive statistic (in the count noun se...
# Inferential statistics                              [Statistical inference is the process of using...
# Statistics, estimators and pivotal quantities       [Consider independent identically distributed ...
# Null hypothesis and alternative hypothesis          [Interpretation of statistical information can...
# Error                                               [Working from a null hypothesis, two broad cat...
# Interval estimation                                 [Most studies only sample part of a population...
# Significance                                        [Statistics rarely give a simple Yes/No type a...
# Examples                                            [Some well-known statistical tests and procedu...
# Exploratory data analysis                           [Exploratory data analysis (EDA) is an approac...
# Misuse                                              [Misuse of statistics can produce subtle but s...
# Misinterpretation: correlation                      [The concept of correlation is particularly no...
# Applied statistics, theoretical statistics and ...  [Applied statistics comprises descriptive stat...
# Machine learning and data mining                    [Machine learning models are statistical and p...
# Statistics in academia                              [Statistics is applicable to a wide variety of...
# Statistical computing                               [The rapid and sustained increases in computin...
# Business statistics                                 [In business, "statistics" is a widely used ma...
# Statistics applied to mathematics or the arts       [Traditionally, statistics was concerned with ...
# Specialized disciplines                             [Statistical techniques are used in a wide ran...
#
#                                                                                                 words  \
# section
# Introduction                                        [Statistics, is, a, mathematical, body, of, sc...
# Mathematical statistics                             [Mathematical, statistics, is, the, applicatio...
# History                                             [The, early, writings, on, statistical, interf...
# Sampling                                            [When, full, census, data, cannot, be, collect...
# Experimental and observational studies              [A, common, goal, for, a, statistical, researc...
# Experiments                                         [The, basic, steps, of, a, statistical, experi...
# Observational study                                 [An, example, of, an, observational, study, is...
# Types of data                                       [Various, attempts, have, been, made, to, prod...
# Descriptive statistics                              [A, descriptive, statistic, (in, the, count, n...
# Inferential statistics                              [Statistical, inference, is, the, process, of,...
# Statistics, estimators and pivotal quantities       [Consider, independent, identically, distribut...
# Null hypothesis and alternative hypothesis          [Interpretation, of, statistical, information,...
# Error                                               [Working, from, a, null, hypothesis,, two, bro...
# Interval estimation                                 [Most, studies, only, sample, part, of, a, pop...
# Significance                                        [Statistics, rarely, give, a, simple, Yes/No, ...
# Examples                                            [Some, well-known, statistical, tests, and, pr...
# Exploratory data analysis                           [Exploratory, data, analysis, (EDA), is, an, a...
# Misuse                                              [Misuse, of, statistics, can, produce, subtle,...
# Misinterpretation: correlation                      [The, concept, of, correlation, is, particular...
# Applied statistics, theoretical statistics and ...  [Applied, statistics, comprises, descriptive, ...
# Machine learning and data mining                    [Machine, learning, models, are, statistical, ...
# Statistics in academia                              [Statistics, is, applicable, to, a, wide, vari...
# Statistical computing                               [The, rapid, and, sustained, increases, in, co...
# Business statistics                                 [In, business,, "statistics", is, a, widely, u...
# Statistics applied to mathematics or the arts       [Traditionally,, statistics, was, concerned, w...
# Specialized disciplines                             [Statistical, techniques, are, used, in, a, wi...
#
#                                                     hyperlinks_count  \
# section
# Introduction                                                      18
# Mathematical statistics                                            3
# History                                                           51
# Sampling                                                          10
# Experimental and observational studies                            10
# Experiments                                                        2
# Observational study                                                1
# Types of data                                                     15
# Descriptive statistics                                             6
# Inferential statistics                                             5
# Statistics, estimators and pivotal quantities                     14
# Null hypothesis and alternative hypothesis                         1
# Error                                                             16
# Interval estimation                                                7
# Significance                                                       5
# Examples                                                           1
# Exploratory data analysis                                          3
# Misuse                                                             8
# Misinterpretation: correlation                                     1
# Applied statistics, theoretical statistics and ...                 4
# Machine learning and data mining                                   1
# Statistics in academia                                             7
# Statistical computing                                             11
# Business statistics                                               21
# Statistics applied to mathematics or the arts                      2
# Specialized disciplines                                            7
#
#                                                     paragraphs_count  \
# section
# Introduction                                                       3
# Mathematical statistics                                            1
# History                                                            8
# Sampling                                                           3
# Experimental and observational studies                             1
# Experiments                                                        2
# Observational study                                                1
# Types of data                                                      4
# Descriptive statistics                                             1
# Inferential statistics                                             1
# Statistics, estimators and pivotal quantities                      6
# Null hypothesis and alternative hypothesis                         3
# Error                                                              6
# Interval estimation                                                2
# Significance                                                       5
# Examples                                                           1
# Exploratory data analysis                                          1
# Misuse                                                             5
# Misinterpretation: correlation                                     1
# Applied statistics, theoretical statistics and ...                 2
# Machine learning and data mining                                   1
# Statistics in academia                                             2
# Statistical computing                                              2
# Business statistics                                                2
# Statistics applied to mathematics or the arts                      1
# Specialized disciplines                                            3
#
#                                                     words_count
# section
# Introduction                                                346
# Mathematical statistics                                      27
# History                                                     758
# Sampling                                                    242
# Experimental and observational studies                      201
# Experiments                                                 153
# Observational study                                         102
# Types of data                                               365
# Descriptive statistics                                       78
# Inferential statistics                                       83
# Statistics, estimators and pivotal quantities               291
# Null hypothesis and alternative hypothesis                  177
# Error                                                       341
# Interval estimation                                         312
# Significance                                                299
# Examples                                                      7
# Exploratory data analysis                                    48
# Misuse                                                      392
# Misinterpretation: correlation                              126
# Applied statistics, theoretical statistics and ...           81
# Machine learning and data mining                             19
# Statistics in academia                                      130
# Statistical computing                                       165
# Business statistics                                         145
# Statistics applied to mathematics or the arts                63
# Specialized disciplines                                     118
